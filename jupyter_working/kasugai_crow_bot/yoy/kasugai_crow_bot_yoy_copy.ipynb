# %%
import pandas as pd

import plotly.express as px
import plotly.graph_objects as go

from business_models import greenplum
from business_models.greenplum import GreenplumManager
from business_models.botolib import Bot

# %%
yoy_sql_wkl = '''
    with source as (

        select date, date - interval '52 weeks' as date_prev, business,
               sum(deliveries) as deliveries,
               sum(gmv) as gmv,
               sum(net_inflow) as net_inflow
        from snb_delivery.dash_bizdev_plan_fact_smb
        where
                scale = 'week'
          and date >= '2022-01-01'
          and country = 'Russia'
          and client_tariff = 'cargo'
          and business in ('C2C','SMB','B2B')
          and plan_name = 'Fact'
        group by 1,2,3
    )

    select
        a.date::date week_dt,
        a.business,
        a.deliveries,
        b.deliveries as deliveries_prev,
        a.gmv,
        b.gmv as gmv_prev,
        a.net_inflow,
        b.net_inflow as net_inflow_prev
    from
        source as a inner join source as b
                               on b.date = a.date_prev
                                   and a.business = b.business
    where a.date >= now()::date - interval '20 weeks'
        and a.date < date_trunc('week', now())
    order by 1,2;
'''

# %%
bot_token = '6329128572:AAHwUlRF7aTcF-f3m2CT-lK3jE8aJ0gZk5Y'
# chat_id = '-1001944611947'
chat_id = '-866072730' # cargo core

bot = Bot(token=bot_token, default_chat_id=chat_id)

# %%
dataframe = greenplum(yoy_sql_wkl)
# Out:
# ERROR in job  launched by /opt/homebrew/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/runpy.py. <class 'sqlalchemy.exc.OperationalError'>:
#  Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database.py", line 67, in wrapper
#     result = func(*args, **kwargs)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 254, in __call__
#     with Connection(self.engine) as connection:
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 78, in __init__
#     self._connection = engine.connect()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3066, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 91, in __init__
#     else engine.raw_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3145, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3115, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2003, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#   Raised exception: True
# (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8), Retrying in 3 seconds...
# ERROR in job  launched by /opt/homebrew/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/runpy.py. <class 'sqlalchemy.exc.OperationalError'>:
#  Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database.py", line 67, in wrapper
#     result = func(*args, **kwargs)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 254, in __call__
#     with Connection(self.engine) as connection:
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 78, in __init__
#     self._connection = engine.connect()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3066, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 91, in __init__
#     else engine.raw_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3145, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3115, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2003, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#   Raised exception: True
# (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8), Retrying in 3 seconds...
# ERROR in job  launched by /opt/homebrew/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/runpy.py. <class 'sqlalchemy.exc.OperationalError'>:
#  Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database.py", line 67, in wrapper
#     result = func(*args, **kwargs)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 254, in __call__
#     with Connection(self.engine) as connection:
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 78, in __init__
#     self._connection = engine.connect()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3066, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 91, in __init__
#     else engine.raw_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3145, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3115, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2003, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#   Raised exception: True
# (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8), Retrying in 5 seconds...
# ERROR in job  launched by /opt/homebrew/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/runpy.py. <class 'sqlalchemy.exc.OperationalError'>:
#  Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# psycopg2.OperationalError: connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database.py", line 67, in wrapper
#     result = func(*args, **kwargs)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 254, in __call__
#     with Connection(self.engine) as connection:
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py", line 78, in __init__
#     self._connection = engine.connect()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3066, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 91, in __init__
#     else engine.raw_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3145, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3115, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2003, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 3112, in _wrap_pool_connect
#     return fn()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 748, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 598, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 198, in raise_
#     raise exception
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py", line 592, in __connect
#     connection = pool._invoke_creator(self)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py", line 576, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 548, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/Users/ghostrider/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py", line 122, in connect
#     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
# sqlalchemy.exc.OperationalError: (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#   Raised exception: True
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3112, in Engine._wrap_pool_connect(self, fn, connection)
#    3111 try:
# -> 3112     return fn()
#    3113 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:301, in Pool.connect(self)
#     294 """Return a DBAPI connection from the pool.
#     295
#     296 The connection is instrumented such that when its
#    (...)
#     299
#     300 """
# --> 301 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:748, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     747 if not fairy:
# --> 748     fairy = _ConnectionRecord.checkout(pool)
#     750     fairy._pool = pool
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     144         with util.safe_reraise():
# --> 145             self._dec_overflow()
#     146 else:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:142, in QueuePool._do_get(self)
#     141 try:
# --> 142     return self._create_connection()
#     143 except:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:247, in Pool._create_connection(self)
#     245 """Called by subclasses to create a new ConnectionRecord."""
# --> 247 return _ConnectionRecord(self)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     361 if connect:
# --> 362     self.__connect(first_connect_check=True)
#     363 self.finalize_callback = deque()
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:598, in _ConnectionRecord.__connect(self, first_connect_check)
#     597     with util.safe_reraise():
# --> 598         pool.logger.debug("Error on connect(): %s", e)
#     599 else:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:592, in _ConnectionRecord.__connect(self, first_connect_check)
#     591 self.starttime = time.time()
# --> 592 connection = pool._invoke_creator(self)
#     593 pool.logger.debug("Created new connection %r", connection)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py:576, in create_engine.<locals>.connect(connection_record)
#     575             return connection
# --> 576 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py:548, in DefaultDialect.connect(self, *cargs, **cparams)
#     546 def connect(self, *cargs, **cparams):
#     547     # inherits the docstring from interfaces.Dialect.connect
# --> 548     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dataframe = greenplum(yoy_sql_wkl)
#
# File ~/Library/Python/3.9/lib/python/site-packages/business_models/util/log.py:322, in retry.<locals>.deco_retry.<locals>.f_retry(*args, **kwargs)
#     318         if value_key is not None \
#     319                 and value_start is not None \
#     320                 and value_increment is not None:
#     321             kwargs[value_key] = value_start + (tries - mtries) * value_increment
# --> 322 return f(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/business_models/databases/database.py:67, in auth.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#      65 # первая попытка выполнить код
#      66 with Handler(raise_exceptions=was_authorized) as h:
# ---> 67     result = func(*args, **kwargs)
#      69 if not h.success:
#      70     getattr(self, authorize_method)()
#
# File ~/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py:254, in DatabaseSql.__call__(self, query, query_file_paths, query_format_kwargs, **kwargs)
#     252 try:
#     253     query = re.subn('%{2}', '%', change_coding(query))[0]
# --> 254     with Connection(self.engine) as connection:
#     255         result = pd.read_sql(text(query).execution_options(autocommit=True),
#     256                              connection, **kwargs)
#     257 except ResourceClosedError:
#
# File ~/Library/Python/3.9/lib/python/site-packages/business_models/databases/database_sql.py:78, in Connection.__init__(self, engine)
#      74 def __init__(self, engine):
#      75     """
#      76     :param engine: подключение к GP
#      77     """
# ---> 78     self._connection = engine.connect()
#      79     self._connection.connect()
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3066, in Engine.connect(self, close_with_result)
#    3051 def connect(self, close_with_result=False):
#    3052     """Return a new :class:`_engine.Connection` object.
#    3053
#    3054     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3063
#    3064     """
# -> 3066     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:91, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      86     self._has_events = _branch_from._has_events
#      87 else:
#      88     self._dbapi_connection = (
#      89         connection
#      90         if connection is not None
# ---> 91         else engine.raw_connection()
#      92     )
#      94     self._transaction = self._nested_transaction = None
#      95     self.__savepoint_seq = 0
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3145, in Engine.raw_connection(self, _connection)
#    3123 def raw_connection(self, _connection=None):
#    3124     """Return a "raw" DBAPI connection from the connection pool.
#    3125
#    3126     The returned object is a proxied version of the DBAPI
#    (...)
#    3143
#    3144     """
# -> 3145     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3115, in Engine._wrap_pool_connect(self, fn, connection)
#    3113 except dialect.dbapi.Error as e:
#    3114     if connection is None:
# -> 3115         Connection._handle_dbapi_exception_noconnection(
#    3116             e, dialect, self
#    3117         )
#    3118     else:
#    3119         util.raise_(
#    3120             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3121         )
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2003, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002 elif should_wrap:
# -> 2003     util.raise_(
#    2004         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005     )
#    2006 else:
#    2007     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3112, in Engine._wrap_pool_connect(self, fn, connection)
#    3110 dialect = self.dialect
#    3111 try:
# -> 3112     return fn()
#    3113 except dialect.dbapi.Error as e:
#    3114     if connection is None:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:301, in Pool.connect(self)
#     293 def connect(self):
#     294     """Return a DBAPI connection from the pool.
#     295
#     296     The connection is instrumented such that when its
#    (...)
#     299
#     300     """
# --> 301     return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:748, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     745 @classmethod
#     746 def _checkout(cls, pool, threadconns=None, fairy=None):
#     747     if not fairy:
# --> 748         fairy = _ConnectionRecord.checkout(pool)
#     750         fairy._pool = pool
#     751         fairy._counter = 0
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#     421         dbapi_connection = rec.get_connection()
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143     except:
#     144         with util.safe_reraise():
# --> 145             self._dec_overflow()
#     146 else:
#     147     return self._do_get()
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:142, in QueuePool._do_get(self)
#     140 if self._inc_overflow():
#     141     try:
# --> 142         return self._create_connection()
#     143     except:
#     144         with util.safe_reraise():
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:247, in Pool._create_connection(self)
#     244 def _create_connection(self):
#     245     """Called by subclasses to create a new ConnectionRecord."""
# --> 247     return _ConnectionRecord(self)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     360 self.__pool = pool
#     361 if connect:
# --> 362     self.__connect(first_connect_check=True)
#     363 self.finalize_callback = deque()
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:598, in _ConnectionRecord.__connect(self, first_connect_check)
#     596 except Exception as e:
#     597     with util.safe_reraise():
# --> 598         pool.logger.debug("Error on connect(): %s", e)
#     599 else:
#     600     if first_connect_check:
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/pool/base.py:592, in _ConnectionRecord.__connect(self, first_connect_check)
#     590 try:
#     591     self.starttime = time.time()
# --> 592     connection = pool._invoke_creator(self)
#     593     pool.logger.debug("Created new connection %r", connection)
#     594     self.connection = connection
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/create.py:576, in create_engine.<locals>.connect(connection_record)
#     574         if connection is not None:
#     575             return connection
# --> 576 return dialect.connect(*cargs, **cparams)
#
# File /opt/homebrew/lib/python3.9/site-packages/sqlalchemy/engine/default.py:548, in DefaultDialect.connect(self, *cargs, **cparams)
#     546 def connect(self, *cargs, **cparams):
#     547     # inherits the docstring from interfaces.Dialect.connect
# --> 548     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/Library/Python/3.9/lib/python/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "gpdb-master.taxi.yandex.net" (2a02:6b8:c0e:a6c:0:1315:92d9:f7fc), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
metrics = ['deliveries', 'gmv']
businesses = ['total', 'B2B']
scale = 'week_dt'

# %%
bot.send_message(message='Время недельного отчета!', chat=chat_id)

i = 0
for b in businesses:

    if b == 'total':
        idf = dataframe.copy()
    else:
        idf = dataframe[dataframe['business']==b]

    idf = idf.groupby([scale]).sum().reset_index()

    for m in metrics:
        idf[f'{m}_yoy'] = (idf[m] - idf[f'{m}_prev']) / idf[f'{m}_prev']

        fig = px.bar(idf, x=scale, y=f'{m}_yoy',
                  template = 'plotly_white',
                  title=f'Cargo_{m}_{b}_yoy')

        fig.add_trace(go.Scatter(
            x=[i for i in idf[scale]],
            y=[i for i in idf[f'{m}_yoy']],
            mode="text",
            name=f"YoY {b} {m}",
            text=[str(round(round(i, 3)*100,1))+'%' for i in idf[f'{m}_yoy']],
            textposition="top center"
        ))
        
        fig.write_image(f"/Users/ghostrider/projects/jupyter_working/kasugai_crow_bot/yoy/fig{i}.png")
        
        bot.send_photo(photo=f'fig{i}.png', chat=chat_id)

        i += 1

        #fig.show()
